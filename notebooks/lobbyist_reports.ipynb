# %%
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from sqlalchemy import create_engine
from splinter import Browser

# %%
#splinter
browser = Browser('chrome', headless=False)
main_url='https://apps.oaklandca.gov/pec/Lobbyist_ReportsFiled.aspx'
browser.visit(main_url)
# Out:
# The chromedriver version (115.0.5790.170) detected in PATH at C:\utilities\chromedriver.exe might not be compatible with the detected chrome version (116.0.5845.188); currently, chromedriver 116.0.5845.96 is recommended for chrome 116.*, so it is advised to delete the driver in PATH and retry

# %%
html=browser.html
soup=BeautifulSoup(html,'html.parser')

# %%
records=[]
tds=soup.find_all('td',class_=['TableRecords_OddLine','TableRecords_EvenLine'])
links = [td.find('a')['href'] for td in tds if td.find('a')]

# %%
def navigation_has_loaded():
    if browser.is_element_present_by_css('.ListNavigation_Next', wait_time=.000001): # Check for next in case on first page
        return True
    elif browser.is_element_present_by_css('.ListNavigation_Previous', wait_time=.000001): # Check for previous in case on last page
        return True
    else: # Navigation has not loaded
        return False

# %%
navigation_has_loaded()
# Out:
# True

# %%
def contact_scrape():
    filing_html=browser.html
    filing_soup=BeautifulSoup(filing_html,'html.parser')
    tds=filing_soup.find_all('tr')
    for td in tds:
        # Check if this row contains 'Nothing reported...'
        if td.find(string="Nothing reported..."):
            continue  # Skip this iteration if found
            # Convert td elements to text and store them in the 'columns' list
        columns = [col.get_text(strip=True) for col in td]
        # You can add validation here to check if the length of columns is as expected
        # For example, if you expect each row to have 8 columns, you can check:
        if len(columns) == 8:
            records.append(columns)
        else:
            print(f"Skipped row with {len(columns)} columns: {columns}")

# %%
def lobbyist_scrape(arg):
  for link in arg:
      browser.visit('https://apps.oaklandca.gov/pec/'+link)
      if navigation_has_loaded():
        while browser.is_element_present_by_css('.ListNavigation_Previous', wait_time=.000001):
          try:
            previous_button=browser.find_by_css('.ListNavigation_Previous')
            previous_button.click()
          except Exception as e:
            print('Reset pages')
            break
        while navigation_has_loaded():
          contact_scrape()
          try:
            next_button = browser.find_by_css('.ListNavigation_Next')
            next_button.click()
            time.sleep(random.uniform(.5, 1))
          except Exception as e: #ends loop on last page
            print(f"Error or end of pages: {e}")
            break
      else:
         contact_scrape()
      if navigation_has_loaded():
        try:
          page_1_button = browser.find_by_xpath('//*[@id="wt133_OutSystemsUIWeb_wt2_block_wtContent_wtMainContent_OutSystemsUIWeb_wt223_block_wtContent_OutSystemsUIWeb_wtSchAAcc_block_wtContent_RichWidgets_wt5_block_wtPageNavigator_ctl00_wtLink8"]')
          page_1_button.click()
        except Exception as e:
          print(f"Error or end of pages: {e}")

# %%
#test
browser.visit(main_url)
records=[]
#lobbyist_scrape()

# %%
def test(arg):
    records=[]
    x=0
    while x<arg:
        if navigation_has_loaded():
            html=browser.html
            soup=BeautifulSoup(html,'html.parser')
            tds=soup.find_all('td',class_=['TableRecords_OddLine','TableRecords_EvenLine'])
            links = [td.find('a')['href'] for td in tds if td.find('a')]
            lobbyist_scrape()
            browser.visit(main_url)
            if navigation_has_loaded():
                try:
                    next_button = browser.find_by_css('.ListNavigation_Next')
                    next_button.click()
                    time.sleep(random.uniform(1, 1.1))
                except Exception as e: #ends loop on last page
                    print(f"Error or end of pages: {e}")
                    break
            else:
                print('bruh 2')
                break
        else:
            print('bruh')
            break
        x+=1

# %%
def full_scrape():
    while True:
        if navigation_has_loaded():
            html=browser.html
            soup=BeautifulSoup(html,'html.parser')
            tds=soup.find_all('td',class_=['TableRecords_OddLine','TableRecords_EvenLine'])
            links=[]
            links = [td.find('a')['href'] for td in tds if td.find('a')]
            print(links)
            lobbyist_scrape(links)
            browser.visit(main_url)
            if navigation_has_loaded():
                try:
                    next_button = browser.find_by_css('.ListNavigation_Next')
                    next_button.click()
                    time.sleep(random.uniform(1, 1.1))
                except Exception as e: #ends loop on last page
                    print(f"Error or end of pages: {e}")
                    break
            else:
                print('bruh 2')
                break
        else:
            print('bruh')
            break

# %%
full_scrape()
# Out:
# ['Lobbyist_Report.aspx?ReportId=35', 'Lobbyist_Report.aspx?ReportId=36', 'Lobbyist_Report.aspx?ReportId=37', 'Lobbyist_Report.aspx?ReportId=38', 'Lobbyist_Report.aspx?ReportId=39', 'Lobbyist_Report.aspx?ReportId=40', 'Lobbyist_Report.aspx?ReportId=41', 'Lobbyist_Report.aspx?ReportId=42', 'Lobbyist_Report.aspx?ReportId=43', 'Lobbyist_Report.aspx?ReportId=44', 'Lobbyist_Report.aspx?ReportId=45', 'Lobbyist_Report.aspx?ReportId=46', 'Lobbyist_Report.aspx?ReportId=47', 'Lobbyist_Report.aspx?ReportId=49', 'Lobbyist_Report.aspx?ReportId=50']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'AT&T', 'AT&T', '430 Bush St., 5th Floor', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Ellwood Commercial Real Estate', 'Patrick Ellwood', '1354 Piedmont Ave.', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Falck Ambulance Northern California', 'Carolina Snypes', '2190 S. McDowell', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Fred Finch Youth and Family Services', 'Tom\xa0 Alexander', '3800 Coolidge Ave.', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Center for Elders Independence', 'Linda Trowbridge', '510 17th St.', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'AT&T', 'AT&T', '430 Bush St., 5th Floor', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Ellwood Commercial Real Estate', 'Patrick Ellwood', '1354 Piedmont Ave.', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Falck Ambulance Northern California', 'Carolina Snypes', '2190 S. McDowell', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Fred Finch Youth and Family Services', 'Tom\xa0 Alexander', '3800 Coolidge Ave.', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Center for Elders Independence', 'Linda Trowbridge', '510 17th St.', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Lyft, Inc.', 'Lyft, Inc.', '185 Berry Street, #5000', 'Yes', '$ 30,000.00', '']
# Skipped row with 7 columns: ['', 'Rubicon Point Partners', 'Rubicon Point Partners', '55 2nd Street', 'Yes', '$ 42,500.00', '']
# Skipped row with 7 columns: ['', 'Strada Investment Group', 'Strada Investment Group', '100 Spear Street, Suite 2080', 'Yes', '$ 12,000.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Lyft, Inc.', 'Lyft, Inc.', '185 Berry Street, #5000', 'Yes', '$ 30,000.00', '']
# Skipped row with 7 columns: ['', 'Rubicon Point Partners', 'Rubicon Point Partners', '55 2nd Street', 'Yes', '$ 42,500.00', '']
# Skipped row with 7 columns: ['', 'Strada Investment Group', 'Strada Investment Group', '100 Spear Street, Suite 2080', 'Yes', '$ 12,000.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Lyft, Inc.', 'Lyft, Inc.', '185 Berry Street, #5000', 'Yes', '$ 30,000.00', '']
# Skipped row with 7 columns: ['', 'Rubicon Point Partners', 'Rubicon Point Partners', '55 2nd Street', 'Yes', '$ 42,500.00', '']
# Skipped row with 7 columns: ['', 'Strada Investment Group', 'Strada Investment Group', '100 Spear Street, Suite 2080', 'Yes', '$ 12,000.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Prologis', 'Prologis', 'Pier 1, Bay 1', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '7000 Coliseum Way', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '7000 Coliseum Way', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '7000 Coliseum Way', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '7000 Coliseum Way', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Redwood Day School', 'John Loeser', '3245 Sheffield Ave.', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', "Bishop O'Dowd High School", 'Kimberley Walsh', '9500 Steans Ave.', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'AT&T', 'AT&T', '430 Bush St', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Clear Channel Outdoor', 'Clear Channel Outdoor', '555 12th Street, Suite 950', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Prologis', 'Prologis', 'Pier 1, Bay 1', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Prologis', 'Prologis', 'Pier 1, Bay 1', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'KeyBanc Capital Markets Inc.', 'KeyBanc Capital Markets Inc.', '1301 5th Avenue, Ste. 2500', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'ARUP Americas Inc.', 'ARUP Americas Inc.', '1330 Broadway', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'ARUP Americas Inc.', 'ARUP Americas Inc.', '1330 Broadway', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'KeyBanc Capital Markets Inc.', 'KeyBanc Capital Markets Inc.', '1301 5th Avenue, Ste. 2500', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'ARUP Americas Inc.', 'ARUP Americas Inc.', '1330 Broadway', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# ['Lobbyist_Report.aspx?ReportId=51', 'Lobbyist_Report.aspx?ReportId=52', 'Lobbyist_Report.aspx?ReportId=54', 'Lobbyist_Report.aspx?ReportId=55', 'Lobbyist_Report.aspx?ReportId=56', 'Lobbyist_Report.aspx?ReportId=57', 'Lobbyist_Report.aspx?ReportId=58', 'Lobbyist_Report.aspx?ReportId=59', 'Lobbyist_Report.aspx?ReportId=60', 'Lobbyist_Report.aspx?ReportId=61', 'Lobbyist_Report.aspx?ReportId=62', 'Lobbyist_Report.aspx?ReportId=65', 'Lobbyist_Report.aspx?ReportId=67', 'Lobbyist_Report.aspx?ReportId=68', 'Lobbyist_Report.aspx?ReportId=69']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '7000 Coliseum Way', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '7000 Coliseum Way', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '7000 Coliseum Way', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '7000 Coliseum Way', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '7000 Coliseum Way', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'American Promotional Events, Inc.', 'American Promotional Events, Inc.', '555 N. Gilbert Street', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Neutron Holdings, Inc. dba Lime', 'Neutron Holdings, Inc. dba Lime', '85 2nd Street', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Kaiser Permanente', 'Kaiser Permanente', '1950 Franklin', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Crown Castle and its Affiliates', 'Crown Castle and its Affiliates', '1220 Augusta Drive', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'The Jordan Company', 'The Jordan Company', '399 Park Avenue, 30th Floor', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Kaiser Permanente', 'Kaiser Permanente', '1950 Franklin Street', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Pacific Gas and Electric Company', 'Pacific Gas and Electric Company', '1330 Broadway, Suite 415', 'Yes', '$ 1,500.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'East Bay Alliance for a Sustainable Economy', "Kate O'Hara", '360 14th Street', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Verizon Communications, Inc. and its Affiliates', 'Verizon Communications, Inc. and its Affiliates', 'c/o 2350 Kerner Blvd, Suite 250', 'Yes', '$ 7,200.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'East Bay Alliance for a Sustainable Economy', 'East Bay Alliance for a Sustainable Economy', '360 14th St., 4th Fl.', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'East Bay Alliance for a Sustainable Economy', "Kate O'Hara", '360 14th Street', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'American Heart Association', 'Elizabeth Velten', '426 17th Street', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'American Heart Association', 'Elizabeth Velten', '426 17th Street', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Google LLC and its Affiliates', 'Google LLC and its Affiliates', 'c/o 28 Liberty Ship Way', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# ['Lobbyist_Report.aspx?ReportId=70', 'Lobbyist_Report.aspx?ReportId=71', 'Lobbyist_Report.aspx?ReportId=72', 'Lobbyist_Report.aspx?ReportId=73', 'Lobbyist_Report.aspx?ReportId=74', 'Lobbyist_Report.aspx?ReportId=75', 'Lobbyist_Report.aspx?ReportId=76', 'Lobbyist_Report.aspx?ReportId=77', 'Lobbyist_Report.aspx?ReportId=78', 'Lobbyist_Report.aspx?ReportId=79', 'Lobbyist_Report.aspx?ReportId=80', 'Lobbyist_Report.aspx?ReportId=81', 'Lobbyist_Report.aspx?ReportId=82', 'Lobbyist_Report.aspx?ReportId=83', 'Lobbyist_Report.aspx?ReportId=84']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', '', 'Revel Transit, Inc. Revel Transit, Inc.', '68 3rd Street', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Car2Go N.A. LLC', 'Car2Go N.A. LLC', '1717 West 6th Street, #425', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Cisco Systems, Inc.', 'Cisco Systems, Inc.', '300 East Tasman Drive', 'Yes', '$ 12,000.00', '']
# Skipped row with 7 columns: ['', 'Hines', 'Hines', '2800 Post Oak Blvd.', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Jacobs', 'Jacobs', '155 Grand Avenue, Suite 800', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Lyft, Inc.', 'Lyft, Inc.', '185 Berry Street, #5000', 'Yes', '$ 25,000.00', '']
# Skipped row with 7 columns: ['', 'MacArthur 76', 'MacArthur 76', '4276 MacArthur Blvd.', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Mill Creek Residential', 'Mill Creek Residential', '411 Borel Avenue, Suite 405', 'Yes', '$ 11,000.00', '']
# Skipped row with 7 columns: ['', 'One Medical', 'One Medical', '110 Sutter Street', 'Yes', '$ 37,500.00', '']
# Skipped row with 7 columns: ['', 'Paradies Lagardere', 'Paradies Lagardere', '2849 Paces Ferry Road', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Rubicon Point Partners', 'Rubicon Point Partners', '55 2nd Street', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Strada Investment Group', 'Strada Investment Group', '100 Spear Street, Suite 2080', 'Yes', '$ 12,000.00', '']
# Skipped row with 7 columns: ['', 'Suffolk Construction', 'Suffolk Construction', '525 Market Street, Suite 2850', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Veritas Investments, Inc.', 'Veritas Investments, Inc.', '500 Washington Street, #448', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Strada Investment Group', 'Strada Investment Group', '100 Spear Street, Suite 2080', 'Yes', '$ 12,000.00', '']
# Skipped row with 7 columns: ['', 'Suffolk Construction', 'Suffolk Construction', '525 Market Street, Suite 2850', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Veritas Investments, Inc.', 'Veritas Investments, Inc.', '500 Washington Street, #448', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"
# Reset pages
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Revel Transit, Inc.', 'Revel Transit, Inc.', '68 3rd Street', 'Yes', '$ 10,000.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Uber Technologies, Inc. and Affiliates', 'Uber Technologies, Inc. and Affiliates', '1455 Market Street', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Lyft, Inc.', 'Lyft, Inc.', '185 Berry Street', 'Yes', '$ 152.73', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Tobacco Free Kids Action Fund', 'Tobacco Free Kids Action Fund', '1400 I Street, N.W. Suite 1200', 'Yes', '$ 178.36', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'The Clorox Company', 'The Clorox Company', '1221 Broadway', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Hospital Council Northern & Central California', 'Hospital Council Northern & Central California', '1215 K Street, Suite 730', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Schnitzer Steel', 'Schnitzer Steel', '1101 Embarcadero West', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'The Clorox Company', 'The Clorox Company', '1221 Broadway', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'JT Supply', 'JT Supply', '1300 Clay St. suite 600', 'No', '$ 1,500.00', '']
# Skipped row with 7 columns: ['', 'Patient Mutual Assistance Collective Corporation', 'Patient Mutual Assistance Collective Corporation', '1840 Embarcadero', 'No', '$ 15,000.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '2020-07-21', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '2020-07-21', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '2020-07-21', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '2020-07-21', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Athletics', 'Oakland Athletics', '2020-07-21', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'The Clorox Company', 'The Clorox Company', '1221 Broadway', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Cresco Labs', 'Cresco Labs', '400 W Erie St., Suite 110', 'Yes', '$ 12,500.00', '']
# Skipped row with 7 columns: ['', 'Kiva Confections', 'Kiva Confections', '699 Lewelling Blvd., #146 - 346', 'Yes', '$ 6,500.00', '']
# Skipped row with 7 columns: ['', '', 'Dr. Barbara Staggers', '5874 Highwood Road', 'Yes', '$ 1,000.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# ['Lobbyist_Report.aspx?ReportId=85', 'Lobbyist_Report.aspx?ReportId=86', 'Lobbyist_Report.aspx?ReportId=89', 'Lobbyist_Report.aspx?ReportId=90', 'Lobbyist_Report.aspx?ReportId=92', 'Lobbyist_Report.aspx?ReportId=93', 'Lobbyist_Report.aspx?ReportId=95', 'Lobbyist_Report.aspx?ReportId=96', 'Lobbyist_Report.aspx?ReportId=98', 'Lobbyist_Report.aspx?ReportId=99', 'Lobbyist_Report.aspx?ReportId=101', 'Lobbyist_Report.aspx?ReportId=102', 'Lobbyist_Report.aspx?ReportId=103', 'Lobbyist_Report.aspx?ReportId=104', 'Lobbyist_Report.aspx?ReportId=105']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'American Heart Association', 'American Heart Association', '426 17th Street', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Centro Legal de la Raza', 'Centro Legal de la Raza', '3400 E. 12th Street', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Centro Legal de la Raza', 'Centro Legal de la Raza', '3400 E. 12th Street', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Education for Change Public Schools', 'Education for Change Public Schools', '333 Hegenberger', 'Yes', '$ 22,500.00', '']
# Skipped row with 7 columns: ['', 'Argent Materials', 'Argent Materials', '8300 Baldwin Street', 'Yes', '$ 9,000.00', '']
# Skipped row with 7 columns: ['', 'Verizon', 'Verizon', '201 Spear Street', 'Yes', '$ 22,500.00', '']
# Skipped row with 7 columns: ['', 'Pacific Charter School Development', 'Pacific Charter School Development', '1111 Broadway', 'Yes', '$ 17,500.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Education for Change Public Schools', 'Education for Change Public Schools', '333 Hegenberger', 'Yes', '$ 22,500.00', '']
# Skipped row with 7 columns: ['', 'Argent Materials', 'Argent Materials', '8300 Baldwin Street', 'Yes', '$ 9,000.00', '']
# Skipped row with 7 columns: ['', 'Verizon', 'Verizon', '201 Spear Street', 'Yes', '$ 22,500.00', '']
# Skipped row with 7 columns: ['', 'Pacific Charter School Development', 'Pacific Charter School Development', '1111 Broadway', 'Yes', '$ 17,500.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Metropolitan Chamber of Commerce', 'Oakland Metropolitan Chamber of Commerce', '1333 Broadway', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Metropolitan Chamber of Commerce', 'Oakland Metropolitan Chamber of Commerce', '1333 Broadway', 'Yes', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Enterprise Rent-A-Car Company of San Francisco, LLC', 'Enterprise Rent-A-Car Company of San Francisco, LLC', '58 2nd Street', 'Yes', '$ 12,500.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Alliance for Californians for Community Empowerment', 'Alliance for Californians for Community Empowerment', '2501 International Blvd.', 'Yes', '$ 250.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Alliance for Californians for Community Empowerment', 'Alliance for Californians for Community Empowerment', '2501 International Blvd.', 'Yes', '$ 500.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Harborside Health Center', 'Harborside Health Center', '1840 Embarcadero', 'No', '$ 10,000.00', '']
# Skipped row with 7 columns: ['', 'Kiva Confections', 'Kiva Confections', '699 Lewelling Blvd., #146 - 346', 'No', '$ 7,000.00', '']
# Skipped row with 7 columns: ['', 'Lehigh-Hanson', 'Lehigh-Hanson', '3000 Executive Parkway,\xa0 Suite 240', 'No', '$ 3,750.00', '']
# Skipped row with 7 columns: ['', 'Cresco Labs', 'Cresco Labs', '400 W Erie St., Suite 110', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', '', 'Dr. Barbara Staggers', '5874 Highwood Road', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Pacific Investment Management Company LLC', 'Pacific Investment Management Company LLC', '650 Newport Center drive', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Pacific Investment Management Company LLC', 'Pacific Investment Management Company LLC', '650 Newport Center drive', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Anschutz Entertainment Group', 'Anschutz Entertainment Group', '7000 Coliseum Way', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', 'California Waste Solutions', 'California Waste Solutions', '1820 10th St.', 'Yes', '$ 22,500.00', '']
# Skipped row with 7 columns: ['', 'Insight Terminal Solutions', 'Insight Terminal Solutions', '6100 Dutchmans Lane #900', 'Yes', '$ 22,500.00', '']
# Skipped row with 7 columns: ['', 'Jobs and Housing Coalition', 'Jobs and Housing Coalition', '300 Frank Ogawa Plaza #460', 'Yes', '$ 45,000.00', '']
# Skipped row with 7 columns: ['', 'Oakland Automobile Dealers Coalition', 'Oakland Automobile Dealers Coalition', '7273 Oakport St', 'No', '$ 0.00', '']
# Skipped row with 7 columns: ['', "Amy's Drive Thru", "Amy's Drive Thru", '1650 Corporate Cir #200', 'No', '$ 0.00', '']
# ...
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Earthjustice', 'Earthjustice', '50 California Street', 'Yes', '$ 797.13', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Earthjustice', 'Earthjustice', '50 California Street', 'Yes', '$ 1,910.94', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Earthjustice', 'Earthjustice', '50 California Street', 'Yes', '$ 1,910.94', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Earthjustice', 'Earthjustice', '50 California Street', 'Yes', '$ 322.46', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Earthjustice', 'Earthjustice', '50 California Street', 'Yes', '$ 322.46', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'CloudKitchen', 'CloudKitchen', '1842 W Washington Blvd.', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'BMO', 'BMO', 'PO Box 0010', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'BuildCasa', 'BuildCasa', '1207 Peralta Street', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'BH Properties', 'BH Properties', '11111 Santa Monica Blvd. Suite 600', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'bp pulse', 'bp pulse', '335 E Middlefield Road', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Insight Terminal Solutions', 'Insight Terminal Solutions', '205 South Martel Avenue', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Schnitzer Steel', 'Schnitzer Steel', '299 SW Clay Street #350', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Bridge Association of Realtors', 'Bridge Association of Realtors', '2855 Telegraph Ave., STE 600', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Martin-Marietta', 'Martin-Marietta', '3000 Executive Parkway,\xa0 Suite 240', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Amazon', 'Amazon', '188 Spear Street', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'IKE Smart City', 'IKE Smart City', '250 N. Hartford Avenue', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Martin Marietta', 'Martin Marietta', '3000 Executive Parkway', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Amazon', 'Amazon', '188 Spear Street', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'IKE Smart City', 'IKE Smart City', '250 N. Hartford Avenue', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Amarok Security', 'Amarok Security', '550 Assembly Street, Fifth Floor', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Kiva Confections', 'Kiva Confections', '699 Lewelling Blvd., #146 - 346', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Martin-Marietta', 'Martin-Marietta', '3000 Executive Parkway, Suite 240', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Amazon', 'Amazon', '188 Spear Street', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'IKE Smart City', 'IKE Smart City', '250 N. Hartford Avenue', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Amarok Security', 'Amarok Security', '550 Assembly Street, Fifth Floor', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Argent Materials', 'Argent Materials', '8300 Baldwin Street', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Verizon', 'Verizon', '201 Spear Street', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Marshall Retail Group', 'Marshall Retail Group', '3755 W. Sunset Road', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Becker Boards', 'Nema Link', '490 43rd Stret', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Vistra Corporate Services Company', 'Brad\xa0 Watson', '6555 Sierra Drive', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'East Bay Asian Local Development Corporation (EBALDC)', 'East Bay Asian Local Development Corporation (EBALDC)', '1825 San Pablo Ave', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Argent Materials', 'Argent Materials', '8300 Baldwin Street', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Verizon', 'Verizon', '201 Spear Street', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Marshall Retail Group', 'Marshall Retail Group', '3755 W. Sunset Road', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Becker Boards', 'Nema Link', '490 43rd Stret', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Vistra Corporate Services Company', 'Brad\xa0 Watson', '6555 Sierra Drive', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'East Bay Asian Local Development Corporation (EBALDC)', 'East Bay Asian Local Development Corporation (EBALDC)', '1825 San Pablo Ave', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Argent Materials', 'Argent Materials', '8300 Baldwin Street', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Verizon', 'Verizon', '201 Spear Street', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Marshall Retail Group', 'Marshall Retail Group', '3755 W. Sunset Road', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Becker Boards', 'Nema Link', '490 43rd Stret', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Vistra Corporate Services Company', 'Brad\xa0 Watson', '6555 Sierra Drive', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'East Bay Asian Local Development Corporation (EBALDC)', 'East Bay Asian Local Development Corporation (EBALDC)', '1825 San Pablo Ave', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Alliance for Californians for Community Empowerment', 'Alliance for Californians for Community Empowerment', '2220 Livingston', 'Yes', '$ 1,000.00', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Oakland Chamber of Commerce', 'Oakland Chamber of Commerce', '1333 Broadway', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Schnitzer Steel', 'Colin Kelly', '1101 Embarcadero West', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Sierra Club', 'Sierra Club', '2101 Webster Street', 'Yes', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# ['Lobbyist_Report.aspx?ReportId=4010', 'Lobbyist_Report.aspx?ReportId=4011', 'Lobbyist_Report.aspx?ReportId=4018']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'American Heart Association', 'Blythe Young', '1111 Broadway', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Pacific Gas and Electric Company', 'Pacific Gas and Electric Company', 'c/o 2350 Kerner Blvd., Suite 250', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Skipped row with 7 columns: ['', 'Organization', 'Name', 'Address', 'Has Activity', 'Amount', '']
# Skipped row with 7 columns: ['', 'Orchestrated Influence', 'Steven Cacela', '5959 Skyline Blvd', 'No', 'Not Stated', '']
# Skipped row with 7 columns: ['', 'Employee', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 7 columns: ['', 'Employer', 'Description', 'Start Service', 'End Service', 'Payments', '']
# Skipped row with 6 columns: ['', 'Date Solicited', 'Recipient', 'Committee', 'Contributor', '']
# Error or end of pages: no elements could be found with css ".ListNavigation_Next"

# %%
contact_df=pd.DataFrame(records[1:],columns=records[0])
#contact_df.drop_duplicates(inplace=True, ignore_index=False)
contact_df=contact_df[['Client','Municipal Decision','Subject','Position','Narrative','City Official']]
contact_df=contact_df[contact_df.Client != 'Client']
contact_df=contact_df.reset_index(drop=True)
contact_df.to_csv('contact_df.csv')
